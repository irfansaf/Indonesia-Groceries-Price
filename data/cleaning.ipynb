# %%
# Cleaning Pricing Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the data xlsx
data = pd.read_excel('harga.xlsx')

# Check the data
data.head()
# Out:
#   No            Komoditas (Rp) 20/ 10/ 2021 21/ 10/ 2021 22/ 10/ 2021  \
# 0  I                     Beras       13,450       13,450       13,450
# 1  1    Beras Kualitas Bawah I       12,050       12,050       12,050
# 2  2   Beras Kualitas Bawah II       11,900       11,900       11,900
# 3  3   Beras Kualitas Medium I       13,400       13,400       13,400
# 4  4  Beras Kualitas Medium II       13,050       13,050       13,050
#
#   25/ 10/ 2021 26/ 10/ 2021 27/ 10/ 2021 28/ 10/ 2021 29/ 10/ 2021  ...  \
# 0       13,450       13,450       13,450       13,450       13,450  ...
# 1       12,050       12,050       12,050       12,050       12,050  ...
# 2       11,900       11,950       11,950       11,950       11,950  ...
# 3       13,400       13,400       13,400       13,400       13,400  ...
# 4       13,050       13,050       13,050       13,050       13,050  ...
#
#   11/ 04/ 2024 12/ 04/ 2024 15/ 04/ 2024 16/ 04/ 2024 17/ 04/ 2024  \
# ...

# %%
# Check the data type
data.dtypes
# Out:
# No                object
# Komoditas (Rp)    object
# 20/ 10/ 2021      object
# 21/ 10/ 2021      object
# 22/ 10/ 2021      object
#                    ...
# 18/ 04/ 2024      object
# 19/ 04/ 2024      object
# 22/ 04/ 2024      object
# 23/ 04/ 2024      object
# 24/ 04/ 2024      object
# Length: 658, dtype: object

# %%
# Check missing values and drop it
data.isnull().sum()

# Drop missing values
data = data.dropna()

# Check the data
data.isnull().sum()

# Check the data
data.head()
# Out:
#   No            Komoditas (Rp) 20/ 10/ 2021 21/ 10/ 2021 22/ 10/ 2021  \
# 0  I                     Beras       13,450       13,450       13,450
# 1  1    Beras Kualitas Bawah I       12,050       12,050       12,050
# 2  2   Beras Kualitas Bawah II       11,900       11,900       11,900
# 3  3   Beras Kualitas Medium I       13,400       13,400       13,400
# 4  4  Beras Kualitas Medium II       13,050       13,050       13,050
#
#   25/ 10/ 2021 26/ 10/ 2021 27/ 10/ 2021 28/ 10/ 2021 29/ 10/ 2021  ...  \
# 0       13,450       13,450       13,450       13,450       13,450  ...
# 1       12,050       12,050       12,050       12,050       12,050  ...
# 2       11,900       11,950       11,950       11,950       11,950  ...
# 3       13,400       13,400       13,400       13,400       13,400  ...
# 4       13,050       13,050       13,050       13,050       13,050  ...
#
#   11/ 04/ 2024 12/ 04/ 2024 15/ 04/ 2024 16/ 04/ 2024 17/ 04/ 2024  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'harga'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
# ...

# %%
# Save the cleaned data to csv and json
data.to_csv('harga_cleaned.csv', index=False)
data.to_json('harga_cleaned.json', orient='records')
